# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
buddymove = 'buddymove_holidayiq.csv'
buddymove = pd.read_csv(buddymove, sep=',',decimal='.', header=0)
buddymove.head()
# Out:
#   User Id  Sports  Religious  Nature  Theatre  Shopping  Picnic
# 0  User 1       2         77      79       69        68      95
# 1  User 2       2         62      76       76        69      68
# 2  User 3       2         50      97       87        50      75
# 3  User 4       2         68      77       95        76      61
# 4  User 5       2         98      54       59        95      86

# %%
buddymove['User Id'] = buddymove['User Id'].str.replace('User ', '')

# Now the 'User Id' column will contain values without the word 'User'
print(buddymove['User Id'])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 244    245
# 245    246
# 246    247
# 247    248
# 248    249
# Name: User Id, Length: 249, dtype: object

# %%
print("\nBasic statistics:")
print(buddymove.describe())
# Out:
# Basic statistics:
#            Sports   Religious      Nature     Theatre    Shopping      Picnic
# count  249.000000  249.000000  249.000000  249.000000  249.000000  249.000000
# mean    11.987952  109.779116  124.518072  116.377510  112.638554  120.401606
# std      6.616501   32.454115   45.639372   32.132696   41.562888   32.633339
# min      2.000000   50.000000   52.000000   59.000000   50.000000   61.000000
# 25%      6.000000   84.000000   89.000000   93.000000   79.000000   92.000000
# 50%     12.000000  104.000000  119.000000  113.000000  104.000000  119.000000
# 75%     18.000000  132.000000  153.000000  138.000000  138.000000  143.000000
# max     25.000000  203.000000  318.000000  213.000000  233.000000  218.000000

# %%
print(buddymove.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User Id    249 non-null    object
#  1   Sports     249 non-null    int64
#  2   Religious  249 non-null    int64
#  3   Nature     249 non-null    int64
#  4   Theatre    249 non-null    int64
#  5   Shopping   249 non-null    int64
#  6   Picnic     249 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 13.7+ KB
# None

# %%
buddymove= buddymove.drop_duplicates(subset=['Sports', 'Religious', 'Nature', 'Theatre', 'Shopping', 'Picnic']).reset_index(drop=True)
buddymove
# Out:
#     User Id  Sports  Religious  Nature  Theatre  Shopping  Picnic
# 0         1       2         77      79       69        68      95
# 1         2       2         62      76       76        69      68
# 2         3       2         50      97       87        50      75
# 3         4       2         68      77       95        76      61
# 4         5       2         98      54       59        95      86
# ..      ...     ...        ...     ...      ...       ...     ...
# 244     245      18        139     148      129       129     168
# 245     246      22        114     228      104        84     168
# 246     247      20        124     178      104       158     174
# 247     248      20        133     149      139       144     213
# 248     249      20        143     149      139       159     143
#
# [249 rows x 7 columns]

# %% [markdown]
# # Data Exploration

# %%
# Scatter Plot Between User Id and Sports
plt.scatter(buddymove['User Id'], buddymove['Sports'], color='blue', alpha=0.5) 
plt.xlabel('User Id')
plt.ylabel('Sports')
plt.xticks(range(0, 270, 20))
plt.show()

# %%
# Scatter Plot Between User Id and Religious
plt.scatter(buddymove['User Id'], buddymove['Religious'], color='blue', alpha=0.5) 
plt.xlabel('User Id')
plt.ylabel('Religious')
plt.xticks(range(0,270,20))
plt.show()

# %%
# Scatter Plot Between User Id and Nature
plt.scatter(buddymove['User Id'], buddymove['Nature'], color='blue', alpha=0.5) 
plt.xlabel('User Id')
plt.ylabel('Nature')
plt.xticks(range(0,270,20))
plt.show()

# %%
# Scatter Plot Between User Id and Theater
plt.scatter(buddymove['User Id'], buddymove['Theatre'], color='blue', alpha=0.5) 
plt.xlabel('User Id')
plt.ylabel('Theatre')
plt.xticks(range(0,270,20))
plt.show()

# %%
# Scatter Plot Between User Id and Shopping
plt.scatter(buddymove['User Id'], buddymove['Shopping'], color='blue', alpha=0.5) 
plt.xlabel('User Id')
plt.ylabel('Shopping')
plt.xticks(range(0,270,20))
plt.show()

# %%
# Scatter Plot Between User Id and Picnic
plt.scatter(buddymove['User Id'], buddymove['Picnic'], color='blue', alpha=0.5) 
plt.xlabel('User Id')
plt.ylabel('Picnic')
plt.xticks(range(0,270,20))
plt.show()

# %%
# Histogram for 'Sports'
plt.figure(figsize=(8, 5))
sns.histplot(x=buddymove['Sports'], bins=20, kde=True, color='green')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Sports Reviews')
plt.show()

# %%
# Histogram for 'Religious'
plt.figure(figsize=(8, 5))
sns.histplot(buddymove['Religious'], bins=20, kde=True, color='lightgreen')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Religious Reviews')
plt.show()

# %%
# Histogram for 'Nature'
plt.figure(figsize=(8, 5))
plt.hist(x=buddymove['Nature'], bins=20, color='lightcoral', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Nature Reviews')
plt.grid(True)
plt.show()

# %%
# Histogram for 'Theatre'
plt.figure(figsize=(8, 5))
plt.hist(buddymove['Theatre'], bins=20, color='orange', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Theatre Reviews')
plt.grid(True)
plt.show()

# %%
# Histogram for 'Shopping'
plt.figure(figsize=(8, 5))
plt.hist(buddymove['Shopping'], bins=20, color='purple', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Shopping Reviews')
plt.grid(True)
plt.show()

# %%
# Histogram for 'Picnic'
plt.figure(figsize=(8, 5))
plt.hist(buddymove['Picnic'], bins=20, color='dodgerblue', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Picnic Reviews')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Distrbution of No. of Reviews per Categories

# %%
# Sum of reviews for each category
category_sums = buddymove.iloc[:, 1:].sum()

# Plotting the distribution of reviews per category
category_sums.plot(kind='bar')
plt.xlabel('Categories')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Reviews per Category')
plt.show()

# %% [markdown]
# ## Boxplot of (No. of Reviews) vs (No. of Users)

# %%
# Boxplot for all activity columns
plt.figure(figsize=(10, 6))
buddymove.boxplot(column=['Sports', 'Religious', 'Nature', 'Theatre', 'Shopping', 'Picnic'])
plt.title('Activity Distributions')
plt.ylabel('Reviews')
plt.show()

# %%
# Adding a column for total reviews per user
buddymove['Total_Reviews'] = buddymove.iloc[:, 1:].sum(axis=1)

# Sorting users by total reviews in descending order
top_users = buddymove.sort_values(by='Total_Reviews', ascending=False).head()

print(top_users[['User Id', 'Total_Reviews']])
# Out:
#     User Id  Total_Reviews
# 243     244            843
# 227     228            824
# 200     201            823
# 194     195            822
# 199     200            819

# %% [markdown]
# ## Correlation Matrix

# %%
# Creating correlation matrix to identify relationships between variables
correlation_matrix = buddymove.iloc[:, 1:-1].corr()

import seaborn as sns
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',  center=0, cbar_kws={'label': 'Value Close to One show Good Correlation'})
plt.title('Correlation Matrix')
plt.show()

# %%
# Generating pair plots
plt.figure(figsize=(10, 6))
pairplot = sns.pairplot(buddymove.iloc[:, 1:-1], diag_kind='kde', plot_kws={'alpha':0.5})
pairplot.fig.suptitle('Scatter and Density Plots', y=1.02)  # Adjust title position
plt.show()

# %% [markdown]
# ## K-MEANS Clustering

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score, davies_bouldin_score, calinski_harabasz_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Relation of Interest of Users between NATURE and THEATRE

# %%
# Applying elbow method
x = buddymove.iloc[:,[3,4]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 772634.6827309236
# 357913.4251677852
# 267774.253270539
# 201199.305086072
# 158469.78804075407
# 136127.25056877526
# 120183.81701501459
# 104148.74216303018
# 90678.5798982532
# 80640.777460113

# %%
# plotting the score
plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Performing K-Means Clustering
kmeans = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Score
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Printing the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Nature')
plt.ylabel('Theatre')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 357913.4251677852
# Silhouette Score: 0.4666 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.8230 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 286.2037 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between SPORTS and RELIGIOUS

# %%
#elbow method
x = buddymove.iloc[:,[1,2]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 272067.8152610442
# 91386.73134863703
# 48829.160187965244
# 31297.826578470675
# 20764.90350697716
# 16937.7632280094
# 13915.86359243525
# 12139.039637528069
# 11126.59707287933
# 9475.460451995354

# %%
# plotting the score
plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

plt.figure(figsize=(8, 5))
# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Sports')
plt.ylabel('Religious')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 91386.73134863703
# Silhouette Score: 0.5690 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.5913 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 488.3447 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between SPORTS and NATURE

# %%
#elbow method
x = buddymove.iloc[:,[1,3]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 527429.1325301204
# 174535.9999316473
# 91911.76987302808
# 62758.684883852264
# 43758.01801170919
# 32069.190539713905
# 26670.62839622381
# 19882.80426291725
# 16518.575738915293
# 14146.517110887977

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

plt.figure(figsize=(8, 5))
# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'purple', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Sports')
plt.ylabel('Nature')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 91911.76987302808
# Silhouette Score: 0.5367 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.5734 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 582.8267 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between RELIGIOUS and NATURE

# %%
#elbow method
x = buddymove.iloc[:,[2,3]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 777783.0200803212
# 424630.06008668244
# 277772.0249755775
# 212755.72681895527
# 154844.95880610327
# 132412.58016086358
# 112003.66529206258
# 93567.4560894661
# 82999.76535601597
# 74453.11825425284

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(b[y_kmeans == 5, 0], b[y_kmeans == 5, 1], s = 100, c = 'pink', label = 'Cluster 6')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Religoius')
plt.ylabel('Nature')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 154864.18683960167
# Silhouette Score: 0.4052 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.7760 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 245.3637 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between SPORTS and THEATRE

# %%
#elbow method
x = buddymove.iloc[:,[1,4]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 266919.47791164654
# 88379.91728701406
# 46132.64049072919
# 29489.261495579707
# 22017.212997946215
# 16532.60504433067
# 14573.448602682796
# 12655.324388821773
# 10920.743888152077
# 9417.767172981392

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

plt.figure(figsize=(8, 5))
# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'blue', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Sports')
plt.ylabel('Theatre')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 46132.64049072919
# Silhouette Score: 0.5101 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.6051 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 588.6674 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between SPORTS and SHOPPING|

# %%
#elbow method
x = buddymove.iloc[:,[1,5]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 439270.4337349398
# 141955.57190775682
# 66313.1304002664
# 41091.52830841002
# 29241.573208466994
# 23262.41804882716
# 19536.670179294393
# 15972.338130904183
# 14025.487716260348
# 12112.979023604341

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

plt.figure(figsize=(8, 5))
# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'orange', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'purple', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Sports')
plt.ylabel('Shopping')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 66313.1304002664
# Silhouette Score: 0.5627 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.5385 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 691.7747 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between SPORTS and PICNIC

# %%
#elbow method
x = buddymove.iloc[:,[1,6]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 274960.8032128514
# 81577.84195216549
# 41250.022165904
# 27462.815286238183
# 18793.105982542045
# 14201.026425986747
# 11406.460456335644
# 9337.099172652188
# 7625.514116384762
# 6783.675764995489

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

plt.figure(figsize=(8, 5))
# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'magenta', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'red', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Sports')
plt.ylabel('Picnic')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 41250.022165904
# Silhouette Score: 0.5611 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.5794 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 696.8827 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between RELIGIOUS and THEATRE

# %%
#elbow method
x = buddymove.iloc[:,[2,4]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 517273.3654618474
# 306523.4092551956
# 179920.29409474367
# 142830.189552948
# 113206.53512019006
# 93022.80339521119
# 75644.18070101942
# 67881.93432423077
# 60098.3921934922
# 53919.647104938136

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'red', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'purple', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Religious')
plt.ylabel('Theatre')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 179920.29409474367
# Silhouette Score: 0.4313 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.7908 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 230.6267 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between RELIGIOUS and SHOPPING

# %%
#elbow method
x = buddymove.iloc[:,[2,5]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 689624.3212851405
# 241643.44136118007
# 128975.21236215974
# 87257.96813725491
# 67792.1734315263
# 58629.21100140937
# 49321.506413580864
# 42975.0169352778
# 38603.57667343652
# 33297.03278375895

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'blue', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Religious')
plt.ylabel('Shopping')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 128975.21236215974
# Silhouette Score: 0.4969 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.6500 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 534.6751 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between RELIGIOUS and PICNIC

# %%
#elbow method
x = buddymove.iloc[:,[2,6]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 525314.6907630522
# 227053.87449864147
# 158482.54417183233
# 122338.80224689456
# 98980.12897542158
# 76671.90280367702
# 64771.85737606331
# 55761.885347303825
# 48888.3929399586
# 42422.705285225136

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters =3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'blue', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'red', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Religious')
plt.ylabel('Picnic')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 158482.54417183233
# Silhouette Score: 0.4190 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.9710 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 284.7024 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between NATURE and SHOPPING

# %%
#elbow method
x = buddymove.iloc[:,[3,5]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 944985.6385542168
# 587280.723275862
# 349314.77223798324
# 242427.16904761904
# 187684.65158087527
# 150999.50482825228
# 120711.04473304474
# 102996.00923932098
# 91846.65431329423
# 83009.85130538579

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'blue', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'orange', label = 'Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 50, c = 'red', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Nature')
plt.ylabel('Shopping')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 242427.16904761904
# Silhouette Score: 0.4440 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.7657 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 236.6715 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between NATURE and PICNIC

# %%
#elbow method
x = buddymove.iloc[:,[3,6]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 780676.0080321286
# 356355.1676614216
# 261774.87893174624
# 183814.29587486744
# 148200.93148679545
# 117774.93173169717
# 99909.30860998244
# 87728.42333750924
# 76766.9049630472
# 69772.58394627318

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'red', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'blue', label = 'Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 50, c = 'black', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Nature')
plt.ylabel('Picnic')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 183814.29587486744
# Silhouette Score: 0.4134 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.7871 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 265.1791 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between THEATRE and SHOPPING

# %%
#elbow method
x = buddymove.iloc[:,[4,5]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 684475.9839357429
# 373735.25922409113
# 232683.70110461337
# 176527.00724759113
# 135150.03461795798
# 115282.0863689497
# 97890.40243904438
# 86635.31194876385
# 76449.87361687193
# 67377.59236273583

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'blue', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Theatre')
plt.ylabel('Shopping')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 232683.70110461337
# Silhouette Score: 0.4223 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.8418 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 238.8240 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between THEATRE and PICNIC

# %%
#elbow method
x = buddymove.iloc[:,[4,6]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 520166.35341365467
# 284688.8975887996
# 167289.79706790124
# 128720.48008818911
# 102405.5927356505
# 86702.72975779188
# 71493.53616900956
# 61756.43910385808
# 55534.61428989689
# 50442.60055005689

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'magenta', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Theatre')
plt.ylabel('Picnic')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 167289.79706790124
# Silhouette Score: 0.4563 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.7701 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 259.4529 (Higher value indicates better clustering)

# %% [markdown]
# ### Relation of Interest of Users between SHOPPING and PICNIC

# %%
#elbow method
x = buddymove.iloc[:,[5,6]].values
score = []

for cluster in range(1,11):
    kmeans = KMeans(n_clusters = cluster, init="k-means++", random_state=10, n_init=10)
    kmeans.fit(x)
    score.append(kmeans.inertia_)
    print(kmeans.inertia_)
# Out:
# 692517.3092369478
# 338070.2858533871
# 222236.7434981685
# 157643.3651669001
# 128435.51282602195
# 100593.02494755246
# 85530.0265367259
# 75622.35648079599
# 67763.43153258177
# 59610.152516879665

# %%
# plotting the score

plt.plot(range(1,11), score)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Running K-Means Clustering to the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42, n_init=10)
y_kmeans = kmeans.fit_predict(x)
print(f"Inertia (WCSS): {kmeans.inertia_}")

# Calculate Evaluation Metrics
silhouette = silhouette_score(x, y_kmeans)
davies_bouldin = davies_bouldin_score(x, y_kmeans)
calinski_harabasz = calinski_harabasz_score(x, y_kmeans)

# Print the Evaluation Scores
print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")

# Visualization of clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50, c = 'green', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50, c = 'black', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'blue', label = 'Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 50, c = 'red', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clustering')
plt.xlabel('Shopping')
plt.ylabel('Picnic')
plt.legend()
plt.show()
# Out:
# Inertia (WCSS): 157643.3651669001
# Silhouette Score: 0.4320 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.8092 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 277.0898 (Higher value indicates better clustering)

# %% [markdown]
# ## DBSCAN

# %%
# Selecting the columns for clustering
X = buddymove[['Sports', 'Religious', 'Nature', 'Theatre', 'Shopping', 'Picnic']]

# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Applying DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=6)
dbscan.fit(X_scaled)
labels = dbscan.labels_

# Adding the cluster labels to the original dataframe
buddymove['Cluster'] = labels

# ploting Results
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='viridis')
plt.xlabel('Sports')
plt.ylabel('Religious')
plt.title('DBSCAN Clustering (SPORTS VS RELIGIOUS)')
plt.show()

plt.scatter(X_scaled[:, 0], X_scaled[:, 2], c=labels, cmap='viridis')
plt.xlabel('Sports')
plt.ylabel('Nature')
plt.title('DBSCAN Clustering (SPORTS VS NATURE)')
plt.show()

plt.scatter(X_scaled[:, 0], X_scaled[:, 3], c=labels, cmap='viridis')
plt.xlabel('Sports')
plt.ylabel('Theatre')
plt.title('DBSCAN Clustering (SPORTS VS THEATRE)')
plt.show()

plt.scatter(X_scaled[:, 0], X_scaled[:, 4], c=labels, cmap='viridis')
plt.xlabel('Sports')
plt.ylabel('Shopping')
plt.title('DBSCAN Clustering (SPORTS VS SHOPPING)')
plt.show()

plt.scatter(X_scaled[:, 0], X_scaled[:, 5], c=labels, cmap='viridis')
plt.xlabel('Sports')
plt.ylabel('Picnic')
plt.title('DBSCAN Clustering (SPORTS VS PICNIC)')
plt.show()

plt.scatter(X_scaled[:, 1], X_scaled[:, 2], c=labels, cmap='viridis')
plt.xlabel('Religious')
plt.ylabel('Nature')
plt.title('DBSCAN Clustering (RELIGIOUS VS NATURE)')
plt.show()

plt.scatter(X_scaled[:, 1], X_scaled[:, 3], c=labels, cmap='viridis')
plt.xlabel('Religious')
plt.ylabel('Theatre)')
plt.title('DBSCAN Clustering (RELIGIOUS VS THEATRE)')
plt.show()

plt.scatter(X_scaled[:, 1], X_scaled[:, 4], c=labels, cmap='viridis')
plt.xlabel('Religious')
plt.ylabel('Shopping')
plt.title('DBSCAN Clustering (RELIGIOUS VS SHOPPING)')
plt.show()

plt.scatter(X_scaled[:, 1], X_scaled[:, 5], c=labels, cmap='viridis')
plt.xlabel('Religious')
plt.ylabel('Picnic')
plt.title('DBSCAN Clustering (RELIGIOUS VS PICNIC)')
plt.show()

plt.scatter(X_scaled[:, 2], X_scaled[:, 3], c=labels, cmap='viridis')
plt.xlabel('Nature')
plt.ylabel('Theatre')
plt.title('DBSCAN Clustering (NATURE VS THEATRE)')
plt.show()

plt.scatter(X_scaled[:, 2], X_scaled[:, 4], c=labels, cmap='viridis')
plt.xlabel('Nature')
plt.ylabel('Shopping')
plt.title('DBSCAN Clustering (NATURE VS SHOPPING)')
plt.show()

plt.scatter(X_scaled[:, 2], X_scaled[:, 5], c=labels, cmap='viridis')
plt.xlabel('Nature')
plt.ylabel('Picnic')
plt.title('DBSCAN Clustering (NATURE VS PICNIC')
plt.show()

plt.scatter(X_scaled[:, 3], X_scaled[:, 4], c=labels, cmap='viridis')
plt.xlabel('Theatre')
plt.ylabel('Shopping')
plt.title('DBSCAN Clustering (THEATRE VS SHOPPING)')
plt.show()

plt.scatter(X_scaled[:, 3], X_scaled[:, 5], c=labels, cmap='viridis')
plt.xlabel('Theatre')
plt.ylabel('Picnic')
plt.title('DBSCAN Clustering (THEATRE VS PICNIC)')
plt.show()

plt.scatter(X_scaled[:, 4], X_scaled[:, 5], c=labels, cmap='viridis')
plt.xlabel('Shopping')
plt.ylabel('Picnic')
plt.title('DBSCAN Clustering (SHOPPING VS PICNIC)')
plt.show()

# %%
# Filter out noise points (-1 cluster label)
valid_clusters = buddymove[buddymove['Cluster'] != -1]

if len(valid_clusters) > 1:  # Ensure there are enough valid clusters for evaluation
    X_valid = X_scaled[buddymove['Cluster'] != -1]  # Filter valid data points
    labels_valid = valid_clusters['Cluster'].values  # Get valid cluster labels

    # Compute clustering evaluation metrics
    silhouette = silhouette_score(X_valid, labels_valid)
    davies_bouldin = davies_bouldin_score(X_valid, labels_valid)
    calinski_harabasz = calinski_harabasz_score(X_valid, labels_valid)

    # Print overall evaluation scores
    print("Overall Clustering Performance:")
    print(f"Silhouette Score: {silhouette:.4f} (Close to one indicates better clustering)")
    print(f"Davies-Bouldin Index: {davies_bouldin:.4f} (Close to zero indicates better clustering)")
    print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f} (Higher value indicates better clustering)")
else:
    print("Not enough valid clusters to compute evaluation metrics.")
# Out:
# Overall Clustering Performance:
# Silhouette Score: 0.7133 (Close to one indicates better clustering)
# Davies-Bouldin Index: 0.3595 (Close to zero indicates better clustering)
# Calinski-Harabasz Index: 152.6959 (Higher value indicates better clustering)
